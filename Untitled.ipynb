# %%
import pandas as d

# %%
rainfall = pd.read_excel("C:/Users/matom/Downloads/Masters Dissertation/Analysis/durban_station_rainfall.xlsx")
rainfall
# Out:
#        YEAR  DOY    T2M  T2M_MAX  T2M_MIN  PRECTOTCORR      PS  WS10M  WS2M  \
# 0      1981   32  24.03    24.78    23.08         1.38  101.52   4.90  4.29
# 1      1981   33  25.73    26.27    24.81         2.58  101.30   8.53  7.11
# 2      1981   34  26.39    27.16    25.79         7.29  100.90   8.51  7.05
# 3      1981   35  25.17    25.87    24.40         0.23  100.88   5.26  4.54
# 4      1981   36  24.94    25.62    24.36        10.85  101.31   8.54  7.17
# ...     ...  ...    ...      ...      ...          ...     ...    ...   ...
# 13167  2025  175  21.26    21.99    20.43         0.30  101.72   6.15  5.21
# 13168  2025  177  21.64    23.96    19.44         2.25  100.47   7.23  6.08
# 13169  2025  178  19.70    20.12    19.18         1.37  101.83   6.82  5.86
# 13170  2025  180  21.50    22.84    20.35         0.02  102.32   4.83  4.16
# 13171  2025  181  21.17    22.02    20.18         0.09  102.42   6.18  5.21
#
# ...

# %%
rainfall.describe()
# Out:
#                YEAR           DOY           T2M       T2M_MAX       T2M_MIN  \
# count  13172.000000  13172.000000  13172.000000  13172.000000  13172.000000
# mean    2003.144473    181.592013     22.417030     23.334635     21.430100
# std       12.860335    113.225641      2.231121      2.255423      2.317023
# min     1981.000000      1.000000     15.360000     16.000000     12.640000
# 25%     1992.000000     77.000000     20.680000     21.610000     19.650000
# 50%     2003.000000    178.000000     22.490000     23.430000     21.490000
# 75%     2014.000000    288.000000     24.250000     25.130000     23.340000
# max     2025.000000    366.000000     28.440000     32.240000     26.930000
#
#         PRECTOTCORR            PS         WS10M          WS2M         WD10M  \
# count  13172.000000  13172.000000  13172.000000  13172.000000  13172.000000
# mean       3.176039    101.522973      6.858476      5.780791    123.041831
# ...

# %%
from sklearn.model_selection import train_test_split

split_index = int(len(rainfall) * 0.8)

train_data = rainfall.iloc[:split_index]
test_data = rainfall.iloc[split_index:]

# %%
train_data
# Out:
#        YEAR  DOY    T2M  T2M_MAX  T2M_MIN  PRECTOTCORR      PS  WS10M  WS2M  \
# 0      1981   32  24.03    24.78    23.08         1.38  101.52   4.90  4.29
# 1      1981   33  25.73    26.27    24.81         2.58  101.30   8.53  7.11
# 2      1981   34  26.39    27.16    25.79         7.29  100.90   8.51  7.05
# 3      1981   35  25.17    25.87    24.40         0.23  100.88   5.26  4.54
# 4      1981   36  24.94    25.62    24.36        10.85  101.31   8.54  7.17
# ...     ...  ...    ...      ...      ...          ...     ...    ...   ...
# 10532  2016  365  22.85    23.38    22.06         0.10  101.69   4.55  3.97
# 10533  2016  366  24.26    24.96    23.16         0.18  101.25   8.86  7.38
# 10534  2017    1  24.78    25.51    24.01         0.17  101.04   7.53  6.28
# 10535  2017    2  24.87    25.78    24.12         0.13  100.77   9.89  8.14
# 10536  2017    3  24.28    25.17    22.86        11.88  101.17   9.97  8.20
#
# ...
